# %%
# For capturing hand coordinates
import cv2
import mediapipe as mp

# For processing data
import csv
import os
import numpy as np
import pandas as pd

# %% [markdown]
# # Find dataset directory

# %%
alphabets = {}

# Get image from dataset
base_dir = './archive'
train_dir = os.path.join(base_dir, 'asl_alphabet_train')

list_subfolders_with_paths = [f.path for f in os.scandir(train_dir) if f.is_dir()]

for i in list_subfolders_with_paths:
    
    # Ignore moving alphabet
    if i.split('\\')[2] not in ['del', 'space', 'nothing','J','Z']:
        alphabets[i.split('\\')[2]] = [f.path for f in os.scandir(i) if f.path.endswith('.jpg')]

dataset = pd.DataFrame.from_dict(alphabets)

# %%
# Should return 24 x 3000
dataset
# Out:
#                                               A  \
# 0        ../archive\asl_alphabet_train\A\A1.jpg
# 1       ../archive\asl_alphabet_train\A\A10.jpg
# 2      ../archive\asl_alphabet_train\A\A100.jpg
# 3     ../archive\asl_alphabet_train\A\A1000.jpg
# 4     ../archive\asl_alphabet_train\A\A1001.jpg
# ...                                         ...
# 2995   ../archive\asl_alphabet_train\A\A995.jpg
# 2996   ../archive\asl_alphabet_train\A\A996.jpg
# 2997   ../archive\asl_alphabet_train\A\A997.jpg
# 2998   ../archive\asl_alphabet_train\A\A998.jpg
# 2999   ../archive\asl_alphabet_train\A\A999.jpg
#
#                                               B  \
# 0        ../archive\asl_alphabet_train\B\B1.jpg
# 1       ../archive\asl_alphabet_train\B\B10.jpg
# 2      ../archive\asl_alphabet_train\B\B100.jpg
# 3     ../archive\asl_alphabet_train\B\B1000.jpg
# 4     ../archive\asl_alphabet_train\B\B1001.jpg
# ...                                         ...
# 2995   ../archive\asl_alphabet_train\B\B995.jpg
# 2996   ../archive\asl_alphabet_train\B\B996.jpg
# 2997   ../archive\asl_alphabet_train\B\B997.jpg
# 2998   ../archive\asl_alphabet_train\B\B998.jpg
# 2999   ../archive\asl_alphabet_train\B\B999.jpg
#
#                                               C  \
# 0        ../archive\asl_alphabet_train\C\C1.jpg
# 1       ../archive\asl_alphabet_train\C\C10.jpg
# 2      ../archive\asl_alphabet_train\C\C100.jpg
# 3     ../archive\asl_alphabet_train\C\C1000.jpg
# 4     ../archive\asl_alphabet_train\C\C1001.jpg
# ...                                         ...
# 2995   ../archive\asl_alphabet_train\C\C995.jpg
# 2996   ../archive\asl_alphabet_train\C\C996.jpg
# 2997   ../archive\asl_alphabet_train\C\C997.jpg
# 2998   ../archive\asl_alphabet_train\C\C998.jpg
# 2999   ../archive\asl_alphabet_train\C\C999.jpg
#
#                                               D  \
# 0        ../archive\asl_alphabet_train\D\D1.jpg
# 1       ../archive\asl_alphabet_train\D\D10.jpg
# 2      ../archive\asl_alphabet_train\D\D100.jpg
# 3     ../archive\asl_alphabet_train\D\D1000.jpg
# 4     ../archive\asl_alphabet_train\D\D1001.jpg
# ...                                         ...
# 2995   ../archive\asl_alphabet_train\D\D995.jpg
# 2996   ../archive\asl_alphabet_train\D\D996.jpg
# 2997   ../archive\asl_alphabet_train\D\D997.jpg
# 2998   ../archive\asl_alphabet_train\D\D998.jpg
# 2999   ../archive\asl_alphabet_train\D\D999.jpg
#
#                                               E  \
# 0        ../archive\asl_alphabet_train\E\E1.jpg
# 1       ../archive\asl_alphabet_train\E\E10.jpg
# 2      ../archive\asl_alphabet_train\E\E100.jpg
# 3     ../archive\asl_alphabet_train\E\E1000.jpg
# 4     ../archive\asl_alphabet_train\E\E1001.jpg
# ...                                         ...
# 2995   ../archive\asl_alphabet_train\E\E995.jpg
# 2996   ../archive\asl_alphabet_train\E\E996.jpg
# 2997   ../archive\asl_alphabet_train\E\E997.jpg
# 2998   ../archive\asl_alphabet_train\E\E998.jpg
# 2999   ../archive\asl_alphabet_train\E\E999.jpg
#
#                                               F  \
# 0        ../archive\asl_alphabet_train\F\F1.jpg
# 1       ../archive\asl_alphabet_train\F\F10.jpg
# 2      ../archive\asl_alphabet_train\F\F100.jpg
# 3     ../archive\asl_alphabet_train\F\F1000.jpg
# 4     ../archive\asl_alphabet_train\F\F1001.jpg
# ...                                         ...
# 2995   ../archive\asl_alphabet_train\F\F995.jpg
# 2996   ../archive\asl_alphabet_train\F\F996.jpg
# 2997   ../archive\asl_alphabet_train\F\F997.jpg
# 2998   ../archive\asl_alphabet_train\F\F998.jpg
# 2999   ../archive\asl_alphabet_train\F\F999.jpg
#
#                                               G  \
# 0        ../archive\asl_alphabet_train\G\G1.jpg
# 1       ../archive\asl_alphabet_train\G\G10.jpg
# 2      ../archive\asl_alphabet_train\G\G100.jpg
# 3     ../archive\asl_alphabet_train\G\G1000.jpg
# 4     ../archive\asl_alphabet_train\G\G1001.jpg
# ...                                         ...
# 2995   ../archive\asl_alphabet_train\G\G995.jpg
# 2996   ../archive\asl_alphabet_train\G\G996.jpg
# 2997   ../archive\asl_alphabet_train\G\G997.jpg
# 2998   ../archive\asl_alphabet_train\G\G998.jpg
# 2999   ../archive\asl_alphabet_train\G\G999.jpg
#
#                                               H  \
# 0        ../archive\asl_alphabet_train\H\H1.jpg
# 1       ../archive\asl_alphabet_train\H\H10.jpg
# 2      ../archive\asl_alphabet_train\H\H100.jpg
# 3     ../archive\asl_alphabet_train\H\H1000.jpg
# 4     ../archive\asl_alphabet_train\H\H1001.jpg
# ...                                         ...
# 2995   ../archive\asl_alphabet_train\H\H995.jpg
# 2996   ../archive\asl_alphabet_train\H\H996.jpg
# 2997   ../archive\asl_alphabet_train\H\H997.jpg
# 2998   ../archive\asl_alphabet_train\H\H998.jpg
# 2999   ../archive\asl_alphabet_train\H\H999.jpg
#
#                                               I  \
# 0        ../archive\asl_alphabet_train\I\I1.jpg
# 1       ../archive\asl_alphabet_train\I\I10.jpg
# 2      ../archive\asl_alphabet_train\I\I100.jpg
# 3     ../archive\asl_alphabet_train\I\I1000.jpg
# 4     ../archive\asl_alphabet_train\I\I1001.jpg
# ...                                         ...
# 2995   ../archive\asl_alphabet_train\I\I995.jpg
# 2996   ../archive\asl_alphabet_train\I\I996.jpg
# 2997   ../archive\asl_alphabet_train\I\I997.jpg
# 2998   ../archive\asl_alphabet_train\I\I998.jpg
# 2999   ../archive\asl_alphabet_train\I\I999.jpg
#
#                                               K  ...  \
# 0        ../archive\asl_alphabet_train\K\K1.jpg  ...
# 1       ../archive\asl_alphabet_train\K\K10.jpg  ...
# 2      ../archive\asl_alphabet_train\K\K100.jpg  ...
# 3     ../archive\asl_alphabet_train\K\K1000.jpg  ...
# 4     ../archive\asl_alphabet_train\K\K1001.jpg  ...
# ...                                         ...  ...
# 2995   ../archive\asl_alphabet_train\K\K995.jpg  ...
# 2996   ../archive\asl_alphabet_train\K\K996.jpg  ...
# 2997   ../archive\asl_alphabet_train\K\K997.jpg  ...
# 2998   ../archive\asl_alphabet_train\K\K998.jpg  ...
# 2999   ../archive\asl_alphabet_train\K\K999.jpg  ...
#
#                                               P  \
# 0        ../archive\asl_alphabet_train\P\P1.jpg
# 1       ../archive\asl_alphabet_train\P\P10.jpg
# 2      ../archive\asl_alphabet_train\P\P100.jpg
# 3     ../archive\asl_alphabet_train\P\P1000.jpg
# 4     ../archive\asl_alphabet_train\P\P1001.jpg
# ...                                         ...
# 2995   ../archive\asl_alphabet_train\P\P995.jpg
# 2996   ../archive\asl_alphabet_train\P\P996.jpg
# 2997   ../archive\asl_alphabet_train\P\P997.jpg
# 2998   ../archive\asl_alphabet_train\P\P998.jpg
# 2999   ../archive\asl_alphabet_train\P\P999.jpg
#
#                                               Q  \
# 0        ../archive\asl_alphabet_train\Q\Q1.jpg
# 1       ../archive\asl_alphabet_train\Q\Q10.jpg
# 2      ../archive\asl_alphabet_train\Q\Q100.jpg
# 3     ../archive\asl_alphabet_train\Q\Q1000.jpg
# 4     ../archive\asl_alphabet_train\Q\Q1001.jpg
# ...                                         ...
# 2995   ../archive\asl_alphabet_train\Q\Q995.jpg
# 2996   ../archive\asl_alphabet_train\Q\Q996.jpg
# 2997   ../archive\asl_alphabet_train\Q\Q997.jpg
# 2998   ../archive\asl_alphabet_train\Q\Q998.jpg
# 2999   ../archive\asl_alphabet_train\Q\Q999.jpg
#
#                                               R  \
# 0        ../archive\asl_alphabet_train\R\R1.jpg
# 1       ../archive\asl_alphabet_train\R\R10.jpg
# 2      ../archive\asl_alphabet_train\R\R100.jpg
# 3     ../archive\asl_alphabet_train\R\R1000.jpg
# 4     ../archive\asl_alphabet_train\R\R1001.jpg
# ...                                         ...
# 2995   ../archive\asl_alphabet_train\R\R995.jpg
# 2996   ../archive\asl_alphabet_train\R\R996.jpg
# 2997   ../archive\asl_alphabet_train\R\R997.jpg
# 2998   ../archive\asl_alphabet_train\R\R998.jpg
# 2999   ../archive\asl_alphabet_train\R\R999.jpg
#
#                                               S  \
# 0        ../archive\asl_alphabet_train\S\S1.jpg
# 1       ../archive\asl_alphabet_train\S\S10.jpg
# 2      ../archive\asl_alphabet_train\S\S100.jpg
# 3     ../archive\asl_alphabet_train\S\S1000.jpg
# 4     ../archive\asl_alphabet_train\S\S1001.jpg
# ...                                         ...
# 2995   ../archive\asl_alphabet_train\S\S995.jpg
# 2996   ../archive\asl_alphabet_train\S\S996.jpg
# 2997   ../archive\asl_alphabet_train\S\S997.jpg
# 2998   ../archive\asl_alphabet_train\S\S998.jpg
# 2999   ../archive\asl_alphabet_train\S\S999.jpg
#
#                                               T  \
# 0        ../archive\asl_alphabet_train\T\T1.jpg
# 1       ../archive\asl_alphabet_train\T\T10.jpg
# 2      ../archive\asl_alphabet_train\T\T100.jpg
# 3     ../archive\asl_alphabet_train\T\T1000.jpg
# 4     ../archive\asl_alphabet_train\T\T1001.jpg
# ...                                         ...
# 2995   ../archive\asl_alphabet_train\T\T995.jpg
# 2996   ../archive\asl_alphabet_train\T\T996.jpg
# 2997   ../archive\asl_alphabet_train\T\T997.jpg
# 2998   ../archive\asl_alphabet_train\T\T998.jpg
# 2999   ../archive\asl_alphabet_train\T\T999.jpg
#
#                                               U  \
# 0        ../archive\asl_alphabet_train\U\U1.jpg
# 1       ../archive\asl_alphabet_train\U\U10.jpg
# 2      ../archive\asl_alphabet_train\U\U100.jpg
# 3     ../archive\asl_alphabet_train\U\U1000.jpg
# 4     ../archive\asl_alphabet_train\U\U1001.jpg
# ...                                         ...
# 2995   ../archive\asl_alphabet_train\U\U995.jpg
# 2996   ../archive\asl_alphabet_train\U\U996.jpg
# 2997   ../archive\asl_alphabet_train\U\U997.jpg
# 2998   ../archive\asl_alphabet_train\U\U998.jpg
# 2999   ../archive\asl_alphabet_train\U\U999.jpg
#
#                                               V  \
# 0        ../archive\asl_alphabet_train\V\V1.jpg
# 1       ../archive\asl_alphabet_train\V\V10.jpg
# 2      ../archive\asl_alphabet_train\V\V100.jpg
# 3     ../archive\asl_alphabet_train\V\V1000.jpg
# 4     ../archive\asl_alphabet_train\V\V1001.jpg
# ...                                         ...
# 2995   ../archive\asl_alphabet_train\V\V995.jpg
# 2996   ../archive\asl_alphabet_train\V\V996.jpg
# 2997   ../archive\asl_alphabet_train\V\V997.jpg
# 2998   ../archive\asl_alphabet_train\V\V998.jpg
# 2999   ../archive\asl_alphabet_train\V\V999.jpg
#
#                                               W  \
# 0        ../archive\asl_alphabet_train\W\W1.jpg
# 1       ../archive\asl_alphabet_train\W\W10.jpg
# 2      ../archive\asl_alphabet_train\W\W100.jpg
# 3     ../archive\asl_alphabet_train\W\W1000.jpg
# 4     ../archive\asl_alphabet_train\W\W1001.jpg
# ...                                         ...
# 2995   ../archive\asl_alphabet_train\W\W995.jpg
# 2996   ../archive\asl_alphabet_train\W\W996.jpg
# 2997   ../archive\asl_alphabet_train\W\W997.jpg
# 2998   ../archive\asl_alphabet_train\W\W998.jpg
# 2999   ../archive\asl_alphabet_train\W\W999.jpg
#
#                                               X  \
# 0        ../archive\asl_alphabet_train\X\X1.jpg
# 1       ../archive\asl_alphabet_train\X\X10.jpg
# 2      ../archive\asl_alphabet_train\X\X100.jpg
# 3     ../archive\asl_alphabet_train\X\X1000.jpg
# 4     ../archive\asl_alphabet_train\X\X1001.jpg
# ...                                         ...
# 2995   ../archive\asl_alphabet_train\X\X995.jpg
# 2996   ../archive\asl_alphabet_train\X\X996.jpg
# 2997   ../archive\asl_alphabet_train\X\X997.jpg
# 2998   ../archive\asl_alphabet_train\X\X998.jpg
# 2999   ../archive\asl_alphabet_train\X\X999.jpg
#
#                                               Y
# 0        ../archive\asl_alphabet_train\Y\Y1.jpg
# 1       ../archive\asl_alphabet_train\Y\Y10.jpg
# 2      ../archive\asl_alphabet_train\Y\Y100.jpg
# 3     ../archive\asl_alphabet_train\Y\Y1000.jpg
# 4     ../archive\asl_alphabet_train\Y\Y1001.jpg
# ...                                         ...
# 2995   ../archive\asl_alphabet_train\Y\Y995.jpg
# 2996   ../archive\asl_alphabet_train\Y\Y996.jpg
# 2997   ../archive\asl_alphabet_train\Y\Y997.jpg
# 2998   ../archive\asl_alphabet_train\Y\Y998.jpg
# 2999   ../archive\asl_alphabet_train\Y\Y999.jpg
#
# [3000 rows x 24 columns]

# %% [markdown]
# # Show random image from directory

# %%
# Showing random train images.

# %matplotlib inline

import matplotlib.pyplot as plt
import matplotlib.image as mpimg

import random

random_column = random.choice(list(dataset.columns))
random_image_path = [i for i in list(dataset.loc[:7, random_column])]

#parameters for our graph, we will output image in a 4x4 configuration
nrows = 4
ncols = 4

#index for iterating
pic_index = 0

#setup matplotlib fig and size it to fit 4x4 img
fig = plt.gcf()
fig.set_size_inches(ncols * 4, nrows * 4)

for i, img_path in enumerate(random_image_path):
    sp = plt.subplot(nrows, ncols, i + 1)
    sp.axis('Off') #disable grid lines
    
    img = mpimg.imread(img_path)
    plt.imshow(img) 

plt.show()
print('Image of alphabet ' + random_column)
# Out:
# Image of alphabet S

# %% [markdown]
# # Generate dataset coordinates using MediaPipe

# %%
file_list = {}

# Adjust how many dataset you want to create
target_success = 5

# Take data in specified amount for creating dataset (make process faster)
# Make sure amount +100 than target success
data = dataset.loc[:10]

for idx in data:
    file_list[idx] = data[idx].values

# %%
# Creating dataset header

landmarks = ['class']
for val in range(1, 22):
#     landmarks += ['x{}'.format(val), 'y{}'.format(val), 'z{}'.format(val)]
    landmarks += ['x{}'.format(val), 'y{}'.format(val)]
    
with open('hand_dataset.csv', mode='w', newline='') as f:
    csv_writer = csv.writer(f, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
    csv_writer.writerow(landmarks)

# %%
# Initialize mediapipe hand

mp_drawing = mp.solutions.drawing_utils
mp_hands = mp.solutions.hands

# %%
with mp_hands.Hands( static_image_mode=True, max_num_hands=2, min_detection_confidence=0.5) as hands:
        
    for idx, files in file_list.items():
        success = 0
        
        for file in files : 
            # Read an image, flip it around y-axis for correct handedness output (see
            # above).
            image = cv2.flip(cv2.imread(file), 1)
            # Convert the BGR image to RGB before processing.
            results = hands.process(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
            
            if success < target_success:
                try :
                    # Extract Hand landmarks

                    for hand_landmark in results.multi_hand_landmarks:
                        right_hand = hand_landmark.landmark

#                     right_hand_row = list(np.array([[landmark.x, landmark.y, landmark.z] for landmark in right_hand]).flatten())
                    right_hand_row = list(np.array([[landmark.x, landmark.y] for landmark in right_hand]).flatten())

                    # Concate rows
                    row = right_hand_row

                    # Append class name 
                    row.insert(0, file.split('\\')[2])

                    # Export to CSV
                    with open('hand_dataset.csv', mode='a', newline='') as f:
                        csv_writer = csv.writer(f, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
                        csv_writer.writerow(row) 
                        
                    success += 1
                    
                except :
                    pass
    
                # Print handedness and draw hand landmarks on the image.

#                 print('Handedness:', results.multi_handedness)
#                 if not results.multi_hand_landmarks:
#                   continue
#                 image_height, image_width, _ = image.shape
#                 annotated_image = image.copy()
#                 for hand_landmarks in results.multi_hand_landmarks:
#                   print('hand_landmarks:', hand_landmarks)
#                   print(
#                       f'Index finger tip coordinates: (',
#                       f'{hand_landmarks.landmark[mp_hands.HandLandmark.INDEX_FINGER_TIP].x * image_width}, '
#                       f'{hand_landmarks.landmark[mp_hands.HandLandmark.INDEX_FINGER_TIP].y * image_height})'
#                   )
#                   mp_drawing.draw_landmarks(
#                       annotated_image, hand_landmarks, mp_hands.HAND_CONNECTIONS)

#                 if not os.path.exists('tmp'):
#                     os.mkdir('./tmp')

#                 cv2.imwrite('./tmp/' + file.split('\\')[2] + str(idx) + '.png', cv2.flip(annotated_image, 1))
            else :
                break
